# %% [markdown]
# # Introduction
# The Nominatim API is a REST API (provided by OpenStreetMap), that returns geographic coordinates (latitude and longitude) from a postal address. If several postal addresses (due to inaccuracy or non-existent street number) corresponding to the request are found, the API returns several coordinates, each time with an `importance` score. The coordinates are given in descending order of importance, so you can select only the first address.

# %%
# Execute the code below :

import requests
import pprint
link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json"
header ={"User_Agent":("Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36 Edg/124.0.0.0") }
r = requests.get(link, headers=header).json()
r
# Out:
# [{'place_id': 45768607,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 1203329854,
#   'lat': '37.7242361',
#   'lon': '15.1789984',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Altarello, Giarre, Catania, Sicilia, 95014, Italia',
#   'boundingbox': ['37.7234970', '37.7249937', '15.1784912', '15.1794786']},
#  {'place_id': 45825211,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 58232256,
#   'lat': '37.6091358',
#   'lon': '15.1596388',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Sciarelle, Acireale, Catania, Sicilia, 95024, Italia',
#   'boundingbox': ['37.6088571', '37.6091358', '15.1591549', '15.1602847']},
#  {'place_id': 46092251,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 167016177,
#   'lat': '37.5676811',
#   'lon': '14.9106709',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Paternò, Catania, Sicilia, 95047, Italia',
#   'boundingbox': ['37.5673863', '37.5680619', '14.9106500', '14.9109837']},
#  {'place_id': 51085534,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 128394486,
#   'lat': '37.6090903',
#   'lon': '15.1604414',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Santa Caterina, Acireale, Catania, Sicilia, 95024, Italia',
#   'boundingbox': ['37.6089805', '37.6091110', '15.1602847', '15.1610300']},
#  {'place_id': 45517592,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 75224730,
#   'lat': '37.4769218',
#   'lon': '14.533668',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Raddusa, Catania, Sicilia, 95040, Italia',
#   'boundingbox': ['37.4763164', '37.4778478', '14.5328669', '14.5348934']},
#  {'place_id': 45803296,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 1125079468,
#   'lat': '37.22508',
#   'lon': '14.5244911',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Caltagirone, Catania, Sicilia, 95041, Italia',
#   'boundingbox': ['37.2250444', '37.2253490', '14.5244318', '14.5249395']},
#  {'place_id': 45831958,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 340599607,
#   'lat': '37.213333',
#   'lon': '14.6341795',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Grammichele, Catania, Sicilia, 95042, Italia',
#   'boundingbox': ['37.2132636', '37.2135294', '14.6341245', '14.6343514']},
#  {'place_id': 46028511,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 223112430,
#   'lat': '37.2970326',
#   'lon': '14.8417094',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Scordia, Catania, Sicilia, 95048, Italia',
#   'boundingbox': ['37.2968575', '37.2971447', '14.8410915', '14.8419764']},
#  {'place_id': 46135429,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 1092232142,
#   'lat': '37.3293593',
#   'lon': '14.7414437',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Palagonia, Catania, Sicilia, 95046, Italia',
#   'boundingbox': ['37.3287325', '37.3297427', '14.7407703', '14.7425445']},
#  {'place_id': 46239386,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 82142425,
#   'lat': '37.3859977',
#   'lon': '14.6916633',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Ramacca, Catania, Sicilia, 95040, Italia',
#   'boundingbox': ['37.3845850', '37.3874239', '14.6912861', '14.6920440']}]

# %%
# r=[
#     {
#         "place_id": 85520744,
#         "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#         "osm_type": "way",
#         "osm_id": 128394486,
#         "lat": "37.6090903",
#         "lon": "15.1604414",
#         "class": "highway",
#         "type": "residential",
#         "place_rank": 26,
#         "importance": 0.10000999999999993,
#         "addresstype": "road",
#         "name": "Via Pietro Mascagni",
#         "display_name": "Via Pietro Mascagni, Santa Caterina, Acireale, Catane, Sicile, 95024, Italie",
#         "boundingbox": [
#             "37.6089805",
#             "37.6091110",
#             "15.1602847",
#             "15.1610300"
#         ]
#     },
#     {
#         "place_id": 78375067,
#         "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#         "osm_type": "way",
#         "osm_id": 58232256,
#         "lat": "37.6091358",
#         "lon": "15.1596388",
#         "class": "highway",
#         "type": "residential",
#         "place_rank": 26,
#         "importance": 0.10000999999999993,
#         "addresstype": "road",
#         "name": "Via Pietro Mascagni",
#         "display_name": "Via Pietro Mascagni, Sciarelle, Acireale, Catane, Sicile, 95024, Italie",
#         "boundingbox": [
#             "37.6088571",
#             "37.6091358",
#             "15.1591549",
#             "15.1602847"
#         ]
#     },
#     {
#         "place_id": 78640544,
#         "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#         "osm_type": "way",
#         "osm_id": 167016177,
#         "lat": "37.5676811",
#         "lon": "14.9106709",
#         "class": "highway",
#         "type": "residential",
#         "place_rank": 26,
#         "importance": 0.10000999999999993,
#         "addresstype": "road",
#         "name": "Via Pietro Mascagni",
#         "display_name": "Via Pietro Mascagni, Paternò, Catane, Sicile, 95047, Italie",
#         "boundingbox": [
#             "37.5673863",
#             "37.5680619",
#             "14.9106500",
#             "14.9109837"
#         ]
#     },
#     {
#         "place_id": 78427165,
#         "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#         "osm_type": "way",
#         "osm_id": 75224730,
#         "lat": "37.4769218",
#         "lon": "14.533668",
#         "class": "highway",
#         "type": "residential",
#         "place_rank": 26,
#         "importance": 0.10000999999999993,
#         "addresstype": "road",
#         "name": "Via Pietro Mascagni",
#         "display_name": "Via Pietro Mascagni, Raddusa, Catane, Sicile, 95040, Italie",
#         "boundingbox": [
#             "37.4763164",
#             "37.4778478",
#             "14.5328669",
#             "14.5348934"
#         ]
#     },
#     {
#         "place_id": 78540959,
#         "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#         "osm_type": "way",
#         "osm_id": 82142425,
#         "lat": "37.3859977",
#         "lon": "14.6916633",
#         "class": "highway",
#         "type": "residential",
#         "place_rank": 26,
#         "importance": 0.10000999999999993,
#         "addresstype": "road",
#         "name": "Via Pietro Mascagni",
#         "display_name": "Via Pietro Mascagni, Ramacca, Catane, Sicile, 95040, Italie",
#         "boundingbox": [
#             "37.3845850",
#             "37.3874239",
#             "14.6912861",
#             "14.6920440"
#         ]
#     },
#     {
#         "place_id": 78603258,
#         "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#         "osm_type": "way",
#         "osm_id": 1092232142,
#         "lat": "37.3293593",
#         "lon": "14.7414437",
#         "class": "highway",
#         "type": "residential",
#         "place_rank": 26,
#         "importance": 0.10000999999999993,
#         "addresstype": "road",
#         "name": "Via Pietro Mascagni",
#         "display_name": "Via Pietro Mascagni, Palagonia, Catane, Sicile, 95046, Italie",
#         "boundingbox": [
#             "37.3287325",
#             "37.3297427",
#             "14.7407703",
#             "14.7425445"
#         ]
#     },
#     {
#         "place_id": 78653015,
#         "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#         "osm_type": "way",
#         "osm_id": 223112430,
#         "lat": "37.2970326",
#         "lon": "14.8417094",
#         "class": "highway",
#         "type": "residential",
#         "place_rank": 26,
#         "importance": 0.10000999999999993,
#         "addresstype": "road",
#         "name": "Via Pietro Mascagni",
#         "display_name": "Via Pietro Mascagni, Scordia, Catane, Sicile, 95048, Italie",
#         "boundingbox": [
#             "37.2968575",
#             "37.2971447",
#             "14.8410915",
#             "14.8419764"
#         ]
#     },
#     {
#         "place_id": 78936384,
#         "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#         "osm_type": "way",
#         "osm_id": 1125079468,
#         "lat": "37.22508",
#         "lon": "14.5244911",
#         "class": "highway",
#         "type": "residential",
#         "place_rank": 26,
#         "importance": 0.10000999999999993,
#         "addresstype": "road",
#         "name": "Via Pietro Mascagni",
#         "display_name": "Via Pietro Mascagni, Caltagirone, Catane, Sicile, 95041, Italie",
#         "boundingbox": [
#             "37.2250444",
#             "37.2253490",
#             "14.5244318",
#             "14.5249395"
#         ]
#     },
#     {
#         "place_id": 78957005,
#         "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#         "osm_type": "way",
#         "osm_id": 340599607,
#         "lat": "37.213333",
#         "lon": "14.6341795",
#         "class": "highway",
#         "type": "residential",
#         "place_rank": 26,
#         "importance": 0.10000999999999993,
#         "addresstype": "road",
#         "name": "Via Pietro Mascagni",
#         "display_name": "Via Pietro Mascagni, Grammichele, Catane, Sicile, 95042, Italie",
#         "boundingbox": [
#             "37.2132636",
#             "37.2135294",
#             "14.6341245",
#             "14.6343514"
#         ]
#     },
#     {
#         "place_id": 78250120,
#         "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#         "osm_type": "way",
#         "osm_id": 78592616,
#         "lat": "37.6077734",
#         "lon": "15.0918042",
#         "class": "highway",
#         "type": "residential",
#         "place_rank": 26,
#         "importance": 0.10000999999999993,
#         "addresstype": "road",
#         "name": "Via Pietro Mascagni",
#         "display_name": "Via Pietro Mascagni, Viscalori, Viagrande, Catane, Sicile, 95029, Italie",
#         "boundingbox": [
#             "37.6074165",
#             "37.6081940",
#             "15.0903677",
#             "15.0930552"
#         ]
#     }
# ]

# %%
# Here we select only the first address (index 0)
print("First address :", r[0])
print("First address longitude :",r[0]['lon'])
print("First address latitude :",r[0]['lat'])
# Out:
# First address : {'place_id': 45768607, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1203329854, 'lat': '37.7242361', 'lon': '15.1789984', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.10000999999999993, 'addresstype': 'road', 'name': 'Via Pietro Mascagni', 'display_name': 'Via Pietro Mascagni, Altarello, Giarre, Catania, Sicilia, 95014, Italia', 'boundingbox': ['37.7234970', '37.7249937', '15.1784912', '15.1794786']}
# First address longitude : 15.1789984
# First address latitude : 37.7242361

# %%
# For ease of use, you can add a limit on the number of items returned:

link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json"
r = requests.get(link, headers=header).json()
print("WITHOUT limit, how many coordinates does this address return?",len(r))

link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json&limit=1"
r = requests.get(link, headers=header).json()
print("WITH limit, how many coordinates does this address return?",len(r))
# Out:
# WITHOUT limit, how many coordinates does this address return? 10
# WITH limit, how many coordinates does this address return? 1

# %% [markdown]
# ## How to create your API query
# It's up to you to modify the string to create the right request URL

# %%
# We observe that the query consists of a fixed part, followed by the address to be searched for.
# An URL cannot contain a " " space character,
# and special characters or accents should be avoided if possible
import re

link_main = 'https://nominatim.openstreetmap.org/?q='
adresse_postale = '54 Via Pietro Mascagni, Catania, Italy'
link_end = '&format=json&limit=1'
ville = adresse_postale.split(",")[1]
pays = adresse_postale.split(",")[-1]
adresse = adresse_postale.split(",")[0]
link = link_main +adresse.replace(" ","+")+ville.replace(" ",",")+pays.replace(" ",",") +link_end

print(link)
# Out:
# https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json&limit=1

# %%
# Create a function here that turns a postal address into a request URL for the Nominatim API,
# then makes the request and returns the coordinates :

def API_address(postal_address):
    link_main = 'https://nominatim.openstreetmap.org/?q='
    link_end = '&format=json&limit=1'
    ville = postal_address.split(",")[1]
    pays = postal_address.split(",")[-1]
    adresse = postal_address.split(",")[0]
    link = link_main +adresse.replace(" ","+")+ville.replace(" ",",")+pays.replace(" ",",") +link_end

    return link

# %%
# Test it here:
address = '54 Via Pietro Mascagni, Catania, Italy'
API_address(address)
# Out:
# 'https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json&limit=1'

# %% [markdown]
# # DataViz
# Latitude & Longitude can be used on visualization tools, whether they are BI tools (PowerBI, Table), or Python DataViz libraries such as Plotly or Folium.
#
# Here we will display a map with Folium.

# %%
# The syntax of Folium is very simple, you start by creating a map centered on a point.
# You can change the default zoom level with the argument "zoom_start".

import folium

# We define a location as a list with 2 values : latitude and longitude.
point = [float(r[0]['lat']), float(r[0]['lon'])]

# We center the map on the location
m = folium.Map(location=point,zoom_start=7)

# We display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f3f2837ea642c14658e6de60935b12e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f3f2837ea642c14658e6de60935b12e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f3f2837ea642c14658e6de60935b12e = L.map(
#                 &quot;map_1f3f2837ea642c14658e6de60935b12e&quot;,
#                 {
#                     center: [37.608989, 15.1226199],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e30a8920005e275f187925b41cb5ce5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4e30a8920005e275f187925b41cb5ce5.addTo(map_1f3f2837ea642c14658e6de60935b12e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Then you can add landmarks and put a clickable comment
m = folium.Map(location=point, )
folium.Marker(
    location=point,
    popup='a good restaurant'
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41d42aa70d73eaf8fa489a6d60404f4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41d42aa70d73eaf8fa489a6d60404f4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41d42aa70d73eaf8fa489a6d60404f4d = L.map(
#                 &quot;map_41d42aa70d73eaf8fa489a6d60404f4d&quot;,
#                 {
#                     center: [37.608989, 15.1226199],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_737e78aee759f6fb8358b99874561f1e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_737e78aee759f6fb8358b99874561f1e.addTo(map_41d42aa70d73eaf8fa489a6d60404f4d);
#
#
#             var marker_052b69224e851d7dcd535eb695913595 = L.marker(
#                 [37.608989, 15.1226199],
#                 {}
#             ).addTo(map_41d42aa70d73eaf8fa489a6d60404f4d);
#
#
#         var popup_3b4dd52de5eac2997fdaa645a5cd97c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d1c24acac9b3999e58fcc1de51811e0 = $(`&lt;div id=&quot;html_9d1c24acac9b3999e58fcc1de51811e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;a good restaurant&lt;/div&gt;`)[0];
#                 popup_3b4dd52de5eac2997fdaa645a5cd97c0.setContent(html_9d1c24acac9b3999e58fcc1de51811e0);
#
#
#
#         marker_052b69224e851d7dcd535eb695913595.bindPopup(popup_3b4dd52de5eac2997fdaa645a5cd97c0)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Challenge
# Here is a DataFrame with restaurants in Catania, Sicily, and their respective addresses. Here is your mission:
# - Create a new column "coordinates", which will store the coordinates corresponding to each address (you can use the function you created previously).
# - Display a map with the 4 restaurant markers. Be careful, the restaurants are very close, remember to set the default zoom level so that it is clearly legible. You can center the map on the first restaurant. And display the name of the restaurant in the tooltip popup.

# %%
import pandas as pd
restaurants = pd.DataFrame([["Gelateria Zio Pietro dal 1964", "Via Porta di Ferro, 47, 95131 Catania CT"],
                            ["A Casa d'Amici","Via Fischetti, 14, 95131 Catania CT"],
                            ["La Bitta", "Via Acquicella Porto, 95121 Catania CT"],
                            ["Steak House", "Via Porta di Ferro, 8, 95100 Catania CT"]
                            ],
                           columns = ["name", "address"])

restaurants
# Out:
#                             name                                   address
# 0  Gelateria Zio Pietro dal 1964  Via Porta di Ferro, 47, 95131 Catania CT
# 1                 A Casa d'Amici       Via Fischetti, 14, 95131 Catania CT
# 2                       La Bitta    Via Acquicella Porto, 95121 Catania CT
# 3                    Steak House   Via Porta di Ferro, 8, 95100 Catania CT

# %%
restaurants["coordinates"]= restaurants['address'].apply(API_address)
restaurants
# Out:
#                             name                                   address  \
# 0  Gelateria Zio Pietro dal 1964  Via Porta di Ferro, 47, 95131 Catania CT
# 1                 A Casa d'Amici       Via Fischetti, 14, 95131 Catania CT
# 2                       La Bitta    Via Acquicella Porto, 95121 Catania CT
# 3                    Steak House   Via Porta di Ferro, 8, 95100 Catania CT
#
#                                          coordinates
# 0  https://nominatim.openstreetmap.org/?q=Via+Por...
# 1  https://nominatim.openstreetmap.org/?q=Via+Fis...
# 2  https://nominatim.openstreetmap.org/?q=Via+Acq...
# 3  https://nominatim.openstreetmap.org/?q=Via+Por...

# %%
m = folium.Map(location=point, zoom_start=15)
for ind, val in enumerate(restaurants["coordinates"]):
      link = val
      r = requests.get(link, headers=header).json()
      point = [float(r[0]['lat']), float(r[0]['lon'])]
      folium.Marker(
          location=point,
          popup= restaurants['name'][ind]
          ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95c024df9cd9c50ae07b65ccd9786b55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95c024df9cd9c50ae07b65ccd9786b55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95c024df9cd9c50ae07b65ccd9786b55 = L.map(
#                 &quot;map_95c024df9cd9c50ae07b65ccd9786b55&quot;,
#                 {
#                     center: [37.608989, 15.1226199],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5940e125366a489a87ed1e4ba6331a6f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5940e125366a489a87ed1e4ba6331a6f.addTo(map_95c024df9cd9c50ae07b65ccd9786b55);
#
#
#             var marker_32b5c383ef973dbe486e565b51909ad2 = L.marker(
#                 [37.5020931, 15.0931951],
#                 {}
#             ).addTo(map_95c024df9cd9c50ae07b65ccd9786b55);
#
#
#         var popup_4f0319d94b0688ba4ccc1e007f127144 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cd235fd8ea0074c24b3c18f6a860a3c7 = $(`&lt;div id=&quot;html_cd235fd8ea0074c24b3c18f6a860a3c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gelateria Zio Pietro dal 1964&lt;/div&gt;`)[0];
#                 popup_4f0319d94b0688ba4ccc1e007f127144.setContent(html_cd235fd8ea0074c24b3c18f6a860a3c7);
#
#
#
#         marker_32b5c383ef973dbe486e565b51909ad2.bindPopup(popup_4f0319d94b0688ba4ccc1e007f127144)
#         ;
#
#
#
#
#             var marker_4480ed04a779edc81447d5b252873cc0 = L.marker(
#                 [37.506171, 15.0943223],
#                 {}
#             ).addTo(map_95c024df9cd9c50ae07b65ccd9786b55);
#
#
#         var popup_6c8713a24b152ba4d98387a840582e63 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3555f7bb725f85ec5d63ef157a0a43f7 = $(`&lt;div id=&quot;html_3555f7bb725f85ec5d63ef157a0a43f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A Casa d&#x27;Amici&lt;/div&gt;`)[0];
#                 popup_6c8713a24b152ba4d98387a840582e63.setContent(html_3555f7bb725f85ec5d63ef157a0a43f7);
#
#
#
#         marker_4480ed04a779edc81447d5b252873cc0.bindPopup(popup_6c8713a24b152ba4d98387a840582e63)
#         ;
#
#
#
#
#             var marker_4d66bb3c69c01dc6d1724cda373b8ba2 = L.marker(
#                 [37.4889155, 15.0833748],
#                 {}
#             ).addTo(map_95c024df9cd9c50ae07b65ccd9786b55);
#
#
#         var popup_777c50f184536abd6721b4f19b092aa7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3ba70b2ff1787c0c7df08e0782257c2 = $(`&lt;div id=&quot;html_f3ba70b2ff1787c0c7df08e0782257c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;La Bitta&lt;/div&gt;`)[0];
#                 popup_777c50f184536abd6721b4f19b092aa7.setContent(html_f3ba70b2ff1787c0c7df08e0782257c2);
#
#
#
#         marker_4d66bb3c69c01dc6d1724cda373b8ba2.bindPopup(popup_777c50f184536abd6721b4f19b092aa7)
#         ;
#
#
#
#
#             var marker_b6da4b9985fc8f5a27f357cda14611f8 = L.marker(
#                 [37.5029335, 15.0930406],
#                 {}
#             ).addTo(map_95c024df9cd9c50ae07b65ccd9786b55);
#
#
#         var popup_f0dbefbd06bf98dd9c6453cac5527e02 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8777c575f932c6f835704f6f049f75d = $(`&lt;div id=&quot;html_c8777c575f932c6f835704f6f049f75d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steak House&lt;/div&gt;`)[0];
#                 popup_f0dbefbd06bf98dd9c6453cac5527e02.setContent(html_c8777c575f932c6f835704f6f049f75d);
#
#
#
#         marker_b6da4b9985fc8f5a27f357cda14611f8.bindPopup(popup_f0dbefbd06bf98dd9c6453cac5527e02)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Remarks on the Nominatim API
# As indicated in the quest, there are many resources for geocoding. Most of them are available by registration, and some require a fee.
#
# The Nominatim API is free and without registration. The disadvantage is that it is relatively slow. If you need to use it in the future, remember to store the results so you don't have to run it several times.
#
# For your knowledge, there is also :
# - the **reverse** address API, which allows you to find the nearest postal address using geographic coordinates.
# - the API from a **CSV file** if you have a lot of addresses to geocode
# - the API **GeoJSON** which allows to obtain a geoJSON format of locations to make choropleth maps
#
#
# All the [documentation is available here](https://nominatim.org/release-docs/develop/api/Search/).
