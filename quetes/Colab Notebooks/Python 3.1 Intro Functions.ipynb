# %% [markdown]
# # Mission 1

# %% [markdown]
# Create a function that returns the sum of 3 + 3 when executed.
# You must use the `return` statement.

# %%
def addition(x,y):
  total=x+y
  return total

addition(3,3)
# Out:
# 6

# %% [markdown]
# # Mission 2

# %% [markdown]
# Create a function that returns the sum of two numbers.
# The user of the function must be able to sum two numbers of his choice, when the function is executed.
# You must not use `input`.

# %%
def addition(x,y):
  total=x+y
  return total

val_1=3
val_2=8

addition(val_1,val_2)
# Out:
# 11

# %% [markdown]
# Question:
# What is a parameter in a function?

# %% [markdown]
# Answer:  le parametre de la fonction est la partie entre les () qui definit les arguments

# %% [markdown]
# # Mission 3

# %% [markdown]
# Create a function that returns the sum of two numbers chosen by the user of the function, in a sentence.
# For example:
# `new_sum_2(3,8)` returns `"The sum of 3 + 8 is equal to 11."`

# %%
def addition(x,y):
  total=x+y
  return(f"la sommede {x} + {y} est egal à {total}")

val_1=3
val_2=8

addition(val_1,val_2)
# Out:
# 'la sommede 3 + 8 est egal à 11'

# %% [markdown]
# # Mission 4
#
# Create a function that returns 2 objects when executed:
# * An object that will be the product of two numbers chosen by the user of the function.
# * A word chosen by the user of the function.

# %%
def addition(x,y,c):
  total=x+y
  reponse=(total,c)
  return reponse
val_1=3
val_2=8
mots="salut"
addition(val_1,val_2,mots)
# Out:
# (11, 'salut')

# %% [markdown]
# Your result must be two objects that are in brackets.
# This is a tuple.
#
# Question:
# Why is the returned object a tuple that contains two objects?
#
# Answer:  c'est tuple car il contient 2 elements de type differant qui sont désignées par un index et qui ne peuvent pas être modifiées

# %% [markdown]
# # Mission 5
#
# Create a function that returns the sum of two numbers when executed.
# Also, your function must return a sentence that simply indicates if the sum of the two numbers chosen by the user is:
# * less than 10
# * between 10 and 50
# * greater than 50
# Again, you must use `return`.

# %%
def addition(x,y):
  total=x+y
  if total < 10 :
    print(f"le total de {x} + {y} est inferieur à 10")
  elif total >50 :
    print(f"le total de {x} + {y} est superieur à 50")
  else:
    print(f"le total de {x} + {y} est compris 10 entre 50")
  return total

val_1=3
val_2=8

addition(val_1,val_2)
# Out:
# le total de 3 + 8 est compris 10 entre 50
# 11
