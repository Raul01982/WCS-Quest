# %%
import pandas as pd


df_salaire= pd.read_csv('C:\Documents\Wild code school\Python\quetes\Business_case\salaries.csv')

# %%
def exploration(df):
    display(
        df.info(),
        'DESCRIBE',
        df.describe(),
        'Nb VALEURS MANQUANTES',
        df.isnull().sum(),
    )


exploration(df_salaire)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26063 entries, 0 to 26062
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           26063 non-null  int64
#  1   experience_level    26063 non-null  object
#  2   employment_type     26063 non-null  object
#  3   job_title           26063 non-null  object
#  4   salary              26063 non-null  int64
#  5   salary_currency     26063 non-null  object
#  6   salary_in_usd       26063 non-null  int64
#  7   employee_residence  26063 non-null  object
#  8   remote_ratio        26063 non-null  int64
#  9   company_location    26063 non-null  object
#  10  company_size        26063 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 2.2+ MB
# None
# 'DESCRIBE'
#           work_year        salary  salary_in_usd  remote_ratio
# count  26063.000000  2.606300e+04   26063.000000  26063.000000
# ...

# %%
df_salaire['company_location'].value_counts()
# Out:
# company_location
# US    23377
# GB      919
# CA      735
# ES      137
# DE      127
#       ...
# EC        1
# AD        1
# QA        1
# GI        1
# MD        1
# Name: count, Length: 79, dtype: int64

# %%
df_salaire['job_title'].value_counts()
# Out:
# job_title
# Data Scientist                   5898
# Data Engineer                    5031
# Data Analyst                     3533
# Machine Learning Engineer        2673
# Research Scientist               1077
#                                  ...
# Power BI Developer                  1
# Applied Research Scientist          1
# Big Data Developer                  1
# Quantitative Research Analyst       1
# CRM Data Analyst                    1
# Name: count, Length: 181, dtype: int64

# %%
df_salaire['job_title'].unique()
# Out:
# array(['Data Scientist', 'Applied Scientist', 'Data Engineer',
#        'Analytics Engineer', 'Data Analyst', 'Research Scientist',
#        'Data Architect', 'Software Engineer', 'AI Specialist',
#        'AI Engineer', 'Machine Learning Engineer', 'Backend Engineer',
#        'Data Lead', 'Data Quality Manager', 'Research Analyst',
#        'Software Developer', 'Machine Learning Scientist', 'Data Manager',
#        'Business Intelligence Analyst',
#        'Machine Learning Platform Engineer', 'Solutions Architect',
#        'Site Reliability Engineer', 'Data Analytics Manager',
#        'Principal Statistical Programmer', 'DevOps Engineer',
#        'Business Intelligence Developer', 'Data Management Analyst',
#        'Research Engineer', 'Data Governance Specialist',
#        'Statistical Programmer', 'Data Specialist', 'Head of AI',
#        'Data Management Manager', 'Data Governance Engineer',
#        'Engineering Manager', 'Business Intelligence Engineer',
# ...

# %%
# np.w

# %%
df_salaire['employment_type'].value_counts()
# Out:
# employment_type
# FT    25968
# PT       44
# CT       37
# FL       14
# Name: count, dtype: int64

# %%
import numpy as np
df_salaire['job_category']= np.where(df_salaire['job_title'].str.contains('Manager') | df_salaire['job_title'].str.contains('Lead') | df_salaire['job_title'].str.contains('Head'), 'Data Manager',
                                     np.where(df_salaire['job_title'].str.contains('Scient'), 'Data Scientist',
                                     np.where(df_salaire['job_title'].str.contains('Analy'), 'Data Analyst',
                                     np.where(df_salaire['job_title'].str.contains('Archite'), 'Data Architect',
                                     np.where(df_salaire['job_title'].str.contains('Engin'), 'Data Engineer','Other')))))

# %%
df_salaire['job_category'].value_counts()
# Out:
# job_category
# Data Engineer     10239
# Data Scientist     8029
# Data Analyst       5037
# Other              1166
# Data Manager        821
# Data Architect      771
# Name: count, dtype: int64

# %%
df_salaire.sample(10)
# Out:
#        work_year experience_level employment_type  \
# 14079       2024               SE              FT
# 15789       2023               MI              FT
# 22780       2023               SE              FT
# 3094        2024               SE              FT
# 10875       2024               EN              FT
# 17483       2023               SE              FT
# 2312        2024               SE              FT
# 17713       2023               EN              FT
# 7858        2024               SE              FT
# 25604       2022               SE              FT
#
#                            job_title  salary salary_currency  salary_in_usd  \
# 14079                   Data Analyst   55200             USD          55200
# 15789                Data Specialist   75000             USD          75000
# 22780                  Data Engineer  146000             USD         146000
# 3094                  Data Scientist  200000             USD         200000
# ...

# %%
df_salaire.to_csv('C:\Documents\Wild code school\Python\quetes\Business_case\salaries.csv')
